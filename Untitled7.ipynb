# %%
{
  "cells": [
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "# 1. Kategori usia\n",
        "usia = int(input('Masukkan usia: '))\n",
        "if 0 <= usia <= 12:\n",
        "    print('Anak-anak')\n",
        "elif usia <= 17:\n",
        "    print('Remaja')\n",
        "elif usia <= 59:\n",
        "    print('Dewasa')\n",
        "else:\n",
        "    print('Lansia')"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "# 2. Harga tiket\n",
        "tiket1 = int(input('Isikan Umur Tiket 1: '))\n",
        "tiket2 = int(input('Isikan Umur Tiket 2: '))\n",
        "tiket3 = int(input('Isikan Umur Tiket 3: '))\n",
        "\n",
        "def harga(umur):\n",
        "    if umur <= 12:\n",
        "        return 10000\n",
        "    elif umur <= 17:\n",
        "        return 15000\n",
        "    elif umur <= 59:\n",
        "        return 25000\n",
        "    else:\n",
        "        return 0\n",
        "\n",
        "total = harga(tiket1) + harga(tiket2) + harga(tiket3)\n",
        "print('Total harga tiket: Rp', total)"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
